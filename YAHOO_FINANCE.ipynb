# %% [markdown]
# <a href="https://colab.research.google.com/github/KunalRoutray/Deep-Learning/blob/main/YAHOO_FINANCE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Import necessary libraries

import pandas as pd
import matplotlib.pyplot as plt
import yfinance as yf
import warnings
warnings.filterwarnings('ignore')

# %%
ticker='tsla'
data=yf.download(ticker)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data.describe()
# Out:
# Price        Close        High         Low        Open        Volume
# Ticker        TSLA        TSLA        TSLA        TSLA          TSLA
# count    20.000000   20.000000   20.000000   20.000000  2.000000e+01
# mean    320.178998  327.007997  312.989580  319.387500  1.087419e+08
# std      13.034863   15.970367   14.179754   16.957494  3.642745e+07
# min     293.940002  296.149994  281.850006  285.959991  2.530767e+07
# 25%     315.574997  318.045006  308.957512  313.635002  8.719350e+07
# 50%     322.104996  329.330002  316.025009  321.489990  1.117121e+08
# 75%     326.174995  332.667496  320.924995  327.642509  1.293518e+08
# max     348.679993  357.540009  340.440002  356.170013  1.907168e+08

# %%
data.tail()
# Out:
# Price            Close        High         Low        Open     Volume
# Ticker            TSLA        TSLA        TSLA        TSLA       TSLA
# Date
# 2025-07-01  300.709991  305.890015  293.209991  298.459991  145085700
# 2025-07-02  315.649994  316.829987  303.820007  312.630005  119483700
# 2025-07-03  315.350006  318.450012  312.760010  317.989990   58042300
# 2025-07-07  293.940002  296.149994  288.769989  291.369995  130514200
# 2025-07-08  298.950012  300.369995  295.641602  296.880005   25307668

# %%
data=yf.download(ticker)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
#use close column analysis
df=data[['Close']]

# %%
#plot the time series
plt.figure(figsize=(15,3))
plt.plot(df['Close'],label='Close price')
plt.title(f'(ticker)Stock Price')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# Fetching the data using a specified period

# %%
ticker='tsla'
period='1y'
data=yf.download(ticker,period=period)
data.tail()
df=data[['Close']]

#plot the time series
plt.figure(figsize=(15,3))
plt.plot(df['Close'],label='Close price')
plt.title(f'(ticker)Stock Price')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.legend()
plt.grid()
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# Fetching the data using a specified period and interval

# %%
ticker='tsla'
period='1mo'
interval='5m'
data=yf.download(ticker,period=period,interval=interval)
data.tail()
df=data[['Close']]

#plot the time series
plt.figure(figsize=(15,3))
plt.plot(df['Close'],label='Close price')
plt.title(f'(ticker)Stock Price')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.legend()
plt.grid()
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# Fetching data using start and end date(YYYY-MM-DD)

# %%
ticker='tsla'
start='2021-04-01'
end='2025-03-31'

data=yf.download(ticker,start=start,end=end)
data.tail()
df=data[['Close']]

#plot the time series
plt.figure(figsize=(15,3))
plt.plot(df['Close'],label='Close price')
plt.title(f'(ticker)Stock Price')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.legend()
plt.grid()
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
